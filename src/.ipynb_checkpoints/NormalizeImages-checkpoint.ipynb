# %%
from PIL import Image
import os
import glob
import cv2 as cv

# %% [markdown]
# ### Convert .webp to .jpg

# %%
input_dir_webp = "../data/webp_unprocessed/"
input_dir_jpeg = "../data/jpeg_unprocessed/"
output_dir = "../data/png_unprocessed/"

if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    
files = glob.glob(os.path.join(input_dir_jpeg, "*.jpg"))
files = files + glob.glob(os.path.join(input_dir_webp, "*.webp"))
# files = glob.glob(os.path.join(input_dir_webp, "*.webp"))

print(files)

for filepath in files: 
    filename = os.path.basename(filepath)
    image_name = os.path.splitext(filename)[0]
    if (filename != "500PesosBack.webp"):
        break

    png_name = os.path.join(output_dir, f"{image_name}.png")
    print(png_name)
    
    img = Image.open(filepath).convert("RGB")
    img.save(png_name, "PNG")
# Out:
# ['../data/jpeg_unprocessed/200PesosFront.jpg', '../data/jpeg_unprocessed/20PesosFront.jpg', '../data/jpeg_unprocessed/200PesosBack.jpg', '../data/jpeg_unprocessed/20PesosBack.jpg', '../data/jpeg_unprocessed/100PesosBack.jpg', '../data/jpeg_unprocessed/1000PesosBack.jpg', '../data/jpeg_unprocessed/500PesosBack.jpg', '../data/jpeg_unprocessed/50PesosPolimeroBack.jpg', '../data/jpeg_unprocessed/100PesosFront.jpg', '../data/jpeg_unprocessed/500PesosFront.jpg', '../data/jpeg_unprocessed/1000PesosFront.jpg', '../data/jpeg_unprocessed/20PesosPolimeroFront.jpg', '../data/jpeg_unprocessed/20PesosPolimeroBack.jpg', '../data/jpeg_unprocessed/50PesosPolimeroFront.jpg', '../data/webp_unprocessed/500PesosFront.webp', '../data/webp_unprocessed/200PesosBack.webp', '../data/webp_unprocessed/500PesosBack.webp', '../data/webp_unprocessed/200PesosFront.webp']
# ../data/png_unprocessed/200PesosFront.png
# ../data/png_unprocessed/20PesosFront.png
# ../data/png_unprocessed/200PesosBack.png
# ../data/png_unprocessed/20PesosBack.png
# ../data/png_unprocessed/100PesosBack.png
# ../data/png_unprocessed/1000PesosBack.png
# ../data/png_unprocessed/500PesosBack.png
# ../data/png_unprocessed/50PesosPolimeroBack.png
# ../data/png_unprocessed/100PesosFront.png
# ../data/png_unprocessed/500PesosFront.png
# ../data/png_unprocessed/1000PesosFront.png
# ../data/png_unprocessed/20PesosPolimeroFront.png
# ../data/png_unprocessed/20PesosPolimeroBack.png
# ../data/png_unprocessed/50PesosPolimeroFront.png
# ../data/png_unprocessed/500PesosFront.png
# ../data/png_unprocessed/200PesosBack.png
# ../data/png_unprocessed/500PesosBack.png
# ../data/png_unprocessed/200PesosFront.png

# %%
import math
import matplotlib.pyplot as plt

def show_images(images, cols=4):
    num_images = len(images)
    rows = math.ceil(num_images / cols)
    
    # Create the figure
    plt.figure(figsize=(15, 5 * rows))
    
    for i, img in enumerate(images):
        # 1. Load the image
        if img is not None:
            # 2. IMPORTANT: Convert BGR (OpenCV default) to RGB (Matplotlib default)
            # img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
            
            # 3. Add to subplot
            plt.subplot(rows, cols, i + 1)
            plt.imshow(img)
            plt.title(f"Image {i+1}")
            plt.axis('off') # Hide the x/y axis numbers
        else:
            print(f"Could not load: {path}")
            
    plt.tight_layout()
    plt.show()

# %%
import numpy as np

def process_image(image): 
    imgray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

    if np.mean(imgray) > 127: 
        _, thresh = cv.threshold(imgray, 240, 255, cv.THRESH_BINARY)
    else:
        _, thresh = cv.threshold(imgray, 1, 255, cv.THRESH_BINARY)

    return thresh

images = [cv.imread(filepath) for filepath in files]
    
input_dir = "../data/jpeg_unprocessed/"

files = glob.glob(os.path.join(input_dir, "*.jpg"))

images = [cv.imread(file) for file in files]

show_images(images)

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import os
import glob

def crop_bill_robust(image_path, trim=15):
    """
    Crops a bill from a solid background.
    trim: Number of pixels to shave off the final crop to eliminate borders.
    """
    # 1. Load the image
    img = cv.imread(image_path)
    if img is None:
        print(f"Error: Could not read {image_path}")
        return None
        
    img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    
    # 2. Heavier blur to wash out internal details (faces/numbers)
    blurred = cv.GaussianBlur(gray, (15, 15), 0)
    
    # 3. Detect edges
    edges = cv.Canny(blurred, 30, 150)
    
    # 4. Morphological Closing to "zip up" any gaps in the bill's outline
    kernel = cv.getStructuringElement(cv.MORPH_RECT, (15, 15))
    closed = cv.morphologyEx(edges, cv.MORPH_CLOSE, kernel)
    
    # 5. Find contours
    contours, _ = cv.findContours(closed, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)
    
    if not contours:
        print("No contours found.")
        return img_rgb
        
    # 6. Get the largest contour
    largest_contour = max(contours, key=cv.contourArea)
    x, y, w, h = cv.boundingRect(largest_contour)
    
    # 7. Apply the trim to shave off the borders, ensuring we don't go out of bounds
    new_x = min(x + trim, img.shape[1])
    new_y = min(y + trim, img.shape[0])
    new_w = max(w - (trim * 2), 1)
    new_h = max(h - (trim * 2), 1)
    
    # 8. Crop using the adjusted coordinates
    cropped_img = img_rgb[new_y:new_y+new_h, new_x:new_x+new_w]
    
    return cropped_img

# --- Processing and Saving Loop ---

input_dir = "../data/jpeg_unprocessed/"
output_dir = "../data/processed_images/"

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

files = glob.glob(os.path.join(input_dir, "*.jpg"))

cropped_images = [crop_bill_robust(file, trim=15) for file in files]
show_images(cropped_images)

for filepath in files: 
    # Extract just the filename without the path
    filename = os.path.basename(filepath)
    
    # Run the robust crop
    print(f"Processing: {filename}")
    cropped_img_rgb = crop_bill_robust(filepath, trim=15)
    
    if cropped_img_rgb is not None:
        # Convert back to BGR for saving with OpenCV
        cropped_img_bgr = cv.cvtColor(cropped_img_rgb, cv.COLOR_RGB2BGR)
        
        save_path = os.path.join(output_dir, f"clean_{filename}")
        cv.imwrite(save_path, cropped_img_bgr)
        print(f"Saved: {save_path}")

print("Batch processing complete!")
# Out:
# Processing: 200PesosFront.jpg
# Saved: ../data/processed_images/clean_200PesosFront.jpg
# Processing: 20PesosFront.jpg
# Saved: ../data/processed_images/clean_20PesosFront.jpg
# Processing: 200PesosBack.jpg
# Saved: ../data/processed_images/clean_200PesosBack.jpg
# Processing: 20PesosBack.jpg
# Saved: ../data/processed_images/clean_20PesosBack.jpg
# Processing: 100PesosBack.jpg
# Saved: ../data/processed_images/clean_100PesosBack.jpg
# Processing: 1000PesosBack.jpg
# Saved: ../data/processed_images/clean_1000PesosBack.jpg
# Processing: 500PesosBack.jpg
# Saved: ../data/processed_images/clean_500PesosBack.jpg
# Processing: 50PesosPolimeroBack.jpg
# Saved: ../data/processed_images/clean_50PesosPolimeroBack.jpg
# Processing: 100PesosFront.jpg
# Saved: ../data/processed_images/clean_100PesosFront.jpg
# Processing: 500PesosFront.jpg
# Saved: ../data/processed_images/clean_500PesosFront.jpg
# Processing: 1000PesosFront.jpg
# Saved: ../data/processed_images/clean_1000PesosFront.jpg
# Processing: 20PesosPolimeroFront.jpg
# Saved: ../data/processed_images/clean_20PesosPolimeroFront.jpg
# Processing: 20PesosPolimeroBack.jpg
# Saved: ../data/processed_images/clean_20PesosPolimeroBack.jpg
# Processing: 50PesosPolimeroFront.jpg
# Saved: ../data/processed_images/clean_50PesosPolimeroFront.jpg
# Batch processing complete!

# %%
import cv2
import os

# 1. List the images you want to crop
input_dir = "../data/png_unprocessed/"
image_files = glob.glob(os.path.join(input_dir, "*.png"))

# 2. Create a folder to save the clean, cropped versions
output_dir = 'cropped_database'
os.makedirs(output_dir, exist_ok=True)

# 3. Loop through each image
for file_name in image_files:
    img = cv2.imread(file_name)
    
    if img is None:
        print(f"Could not find {file_name}. Please check the spelling.")
        continue
        
    print(f"Now cropping: {file_name}")
    print("-> Draw a box using your mouse.")
    print("-> Press ENTER or SPACE to confirm the crop.")
    print("-> Press 'c' to cancel and skip to the next image.")
    
    # 4. Open the interactive cropping window
    # Note: This will open a NEW window on your computer, outside of the browser!
    x, y, w, h = cv2.selectROI("Manual Banknote Cropper", img, showCrosshair=True, fromCenter=False)
    
    # 5. If you successfully drew a box (width and height are greater than 0)
    if w > 0 and h > 0:
        # Slice the numpy array using the coordinates you just drew
        cropped_img = img[y:y+h, x:x+w]
        
        # Save it to the new folder
        save_path = os.path.join(output_dir, f"clean_{file_name}")
        cv2.imwrite(save_path, cropped_img)
        print(f"Success! Saved to {save_path}\n")
    else:
        print("Skipped.\n")
        
# 6. Clean up and close the window when the loop finishes
cv2.destroyAllWindows()
print("All done! Check your 'cropped_database' folder.")
# Out:
# Now cropping: ../data/png_unprocessed/500PesosBack.png
# -> Draw a box using your mouse.
# -> Press ENTER or SPACE to confirm the crop.
# -> Press 'c' to cancel and skip to the next image.
# QFontDatabase: Cannot find font directory /home/federicovareika/Facultad/Intercambio/PID/trabajo-pid-reconocimiento-dinero/.venv/lib/python3.13/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/federicovareika/Facultad/Intercambio/PID/trabajo-pid-reconocimiento-dinero/.venv/lib/python3.13/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/federicovareika/Facultad/Intercambio/PID/trabajo-pid-reconocimiento-dinero/.venv/lib/python3.13/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/federicovareika/Facultad/Intercambio/PID/trabajo-pid-reconocimiento-dinero/.venv/lib/python3.13/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/federicovareika/Facultad/Intercambio/PID/trabajo-pid-reconocimiento-dinero/.venv/lib/python3.13/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# Success! Saved to cropped_database/clean_../data/png_unprocessed/500PesosBack.png
#
# Now cropping: ../data/png_unprocessed/50PesosPolimeroBack.png
# -> Draw a box using your mouse.
# -> Press ENTER or SPACE to confirm the crop.
# -> Press 'c' to cancel and skip to the next image.
# Skipped.
#
# Now cropping: ../data/png_unprocessed/200PesosFront.png
# -> Draw a box using your mouse.
# -> Press ENTER or SPACE to confirm the crop.
# -> Press 'c' to cancel and skip to the next image.
# Skipped.
#
# Now cropping: ../data/png_unprocessed/1000PesosBack.png
# -> Draw a box using your mouse.
# -> Press ENTER or SPACE to confirm the crop.
# -> Press 'c' to cancel and skip to the next image.
# Skipped.
#
# Now cropping: ../data/png_unprocessed/20PesosPolimeroBack.png
# -> Draw a box using your mouse.
# -> Press ENTER or SPACE to confirm the crop.
# -> Press 'c' to cancel and skip to the next image.
# Skipped.
#
# Now cropping: ../data/png_unprocessed/50PesosPolimeroFront.png
# -> Draw a box using your mouse.
# -> Press ENTER or SPACE to confirm the crop.
# -> Press 'c' to cancel and skip to the next image.
# Skipped.
#
# Now cropping: ../data/png_unprocessed/20PesosBack.png
# -> Draw a box using your mouse.
# -> Press ENTER or SPACE to confirm the crop.
# -> Press 'c' to cancel and skip to the next image.
# Skipped.
#
# Now cropping: ../data/png_unprocessed/20PesosPolimeroFront.png
# -> Draw a box using your mouse.
# -> Press ENTER or SPACE to confirm the crop.
# -> Press 'c' to cancel and skip to the next image.
# Skipped.
#
# Now cropping: ../data/png_unprocessed/1000PesosFront.png
# -> Draw a box using your mouse.
# -> Press ENTER or SPACE to confirm the crop.
# -> Press 'c' to cancel and skip to the next image.
# Skipped.
#
# Now cropping: ../data/png_unprocessed/20PesosFront.png
# -> Draw a box using your mouse.
# -> Press ENTER or SPACE to confirm the crop.
# -> Press 'c' to cancel and skip to the next image.
# Skipped.
#
# Now cropping: ../data/png_unprocessed/100PesosBack.png
# -> Draw a box using your mouse.
# -> Press ENTER or SPACE to confirm the crop.
# -> Press 'c' to cancel and skip to the next image.
# Skipped.
#
# Now cropping: ../data/png_unprocessed/200PesosBack.png
# -> Draw a box using your mouse.
# -> Press ENTER or SPACE to confirm the crop.
# -> Press 'c' to cancel and skip to the next image.
# Skipped.
#
# Now cropping: ../data/png_unprocessed/100PesosFront.png
# -> Draw a box using your mouse.
# -> Press ENTER or SPACE to confirm the crop.
# -> Press 'c' to cancel and skip to the next image.
# Skipped.
#
# Now cropping: ../data/png_unprocessed/500PesosFront.png
# -> Draw a box using your mouse.
# -> Press ENTER or SPACE to confirm the crop.
# -> Press 'c' to cancel and skip to the next image.
# Skipped.
#
# All done! Check your 'cropped_database' folder.

# %%
import cv2 as cv
import os
import glob

# 1. Setup directories
input_dir = "../data/png_unprocessed/"
output_dir = "../data/processed_images/"
os.makedirs(output_dir, exist_ok=True)

# 2. Get all files
files = glob.glob(os.path.join(input_dir, "*.png"))

# 3. Loop through and manually crop
for filepath in files:
    filename = os.path.basename(filepath)
    img = cv.imread(filepath)
    
    if img is None:
        continue
        
    print(f"Cropping: {filename} | Draw box -> Press SPACE to save -> 'c' to skip")
    
    # Opens the interactive window
    x, y, w, h = cv.selectROI("Manual Crop (Press SPACE to confirm)", img, showCrosshair=True, fromCenter=False)
    
    # If a box was drawn, save it
    if w > 0 and h > 0:
        cropped_img = img[y:y+h, x:x+w]
        save_path = os.path.join(output_dir, f"clean_{filename}")
        cv.imwrite(save_path, cropped_img)
        print(f"Saved perfectly to {save_path}\n")
    else:
        print("Skipped.\n")

cv.destroyAllWindows()
print("Manual cropping complete!")
# Out:
# Cropping: 500PesosBack.png | Draw box -> Press SPACE to save -> 'c' to skip
# Saved perfectly to ../data/processed_images/clean_500PesosBack.png
#
# Cropping: 50PesosPolimeroBack.png | Draw box -> Press SPACE to save -> 'c' to skip
# Saved perfectly to ../data/processed_images/clean_50PesosPolimeroBack.png
#
# Cropping: 200PesosFront.png | Draw box -> Press SPACE to save -> 'c' to skip
# Saved perfectly to ../data/processed_images/clean_200PesosFront.png
#
# Cropping: 1000PesosBack.png | Draw box -> Press SPACE to save -> 'c' to skip
# Saved perfectly to ../data/processed_images/clean_1000PesosBack.png
#
# Cropping: 20PesosPolimeroBack.png | Draw box -> Press SPACE to save -> 'c' to skip
# Saved perfectly to ../data/processed_images/clean_20PesosPolimeroBack.png
#
# Cropping: 50PesosPolimeroFront.png | Draw box -> Press SPACE to save -> 'c' to skip
# Saved perfectly to ../data/processed_images/clean_50PesosPolimeroFront.png
#
# Cropping: 20PesosBack.png | Draw box -> Press SPACE to save -> 'c' to skip
# Saved perfectly to ../data/processed_images/clean_20PesosBack.png
#
# Cropping: 20PesosPolimeroFront.png | Draw box -> Press SPACE to save -> 'c' to skip
# Saved perfectly to ../data/processed_images/clean_20PesosPolimeroFront.png
#
# Cropping: 1000PesosFront.png | Draw box -> Press SPACE to save -> 'c' to skip
# Saved perfectly to ../data/processed_images/clean_1000PesosFront.png
#
# Cropping: 20PesosFront.png | Draw box -> Press SPACE to save -> 'c' to skip
# Saved perfectly to ../data/processed_images/clean_20PesosFront.png
#
# Cropping: 100PesosBack.png | Draw box -> Press SPACE to save -> 'c' to skip
# Saved perfectly to ../data/processed_images/clean_100PesosBack.png
#
# Cropping: 200PesosBack.png | Draw box -> Press SPACE to save -> 'c' to skip
# Saved perfectly to ../data/processed_images/clean_200PesosBack.png
#
# Cropping: 100PesosFront.png | Draw box -> Press SPACE to save -> 'c' to skip
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# Select a ROI andSaved perfectly to ../data/processed_images/clean_100PesosFront.png
#
# Cropping: 500PesosFront.png | Draw box -> Press SPACE to save -> 'c' to skip
# Saved perfectly to ../data/processed_images/clean_500PesosFront.png
#
# Manual cropping complete!
