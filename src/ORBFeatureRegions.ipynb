# %%
import cv2
import os
import glob
import numpy as np

input_dir = "../data/bill_processing/reference_components/"
output_db_dir = "../data/database/orb_database/"
output_vis_dir = "../data/database/orb_visuals/"

os.makedirs(output_db_dir, exist_ok=True)
os.makedirs(output_vis_dir, exist_ok=True)

orb = cv2.ORB_create(nfeatures=500)

files = glob.glob(os.path.join(input_dir, "*.png"))

print(f"Iniciando extracción ORB desde: {input_dir}\n")

for filepath in files:
    filename = os.path.basename(filepath)
    base_name = os.path.splitext(filename)[0]
    
    img = cv2.imread(filepath)
    if img is None:
        print(f"Error: No se pudo cargar {filename}.")
        continue
        
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Detección y descripción
    kp, des = orb.detectAndCompute(gray, None)
    
    if des is not None:
        # Almacenamiento de descriptores
        db_save_path = os.path.join(output_db_dir, f"{base_name}.npy")
        np.save(db_save_path, des)
        
        # Generación de visualización técnica
        img_with_kp = cv2.drawKeypoints(
            img, kp, None, 
            color=(0, 255, 0), 
            flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS
        )
        
        vis_save_path = os.path.join(output_vis_dir, f"{base_name}_orb_keypoints.jpg")
        cv2.imwrite(vis_save_path, img_with_kp)
        
        print(f"Procesado: {filename} ({len(kp)} descriptores)")
    else:
        print(f"Aviso: No se detectaron características en {filename}.")

print("\nExtracción finalizada. Datos guardados en la base de datos ORB.")
# Out:
# Iniciando extracción ORB desde: ../data/bill_processing/reference_components/
#
# Aviso: No se detectaron características en norm_clean_1000PesosBack_comp_1.png.
# Aviso: No se detectaron características en norm_clean_1000PesosBack_comp_3.png.
# Procesado: norm_clean_1000PesosBack_comp_4.png (448 descriptores)
# Aviso: No se detectaron características en norm_clean_1000PesosFront_comp_1.png.
# Procesado: norm_clean_1000PesosFront_comp_3.png (24 descriptores)
# Procesado: norm_clean_1000PesosFront_comp_4.png (441 descriptores)
# Aviso: No se detectaron características en norm_clean_100PesosBack_comp_1.png.
# Procesado: norm_clean_100PesosBack_comp_3.png (16 descriptores)
# Procesado: norm_clean_100PesosBack_comp_4.png (476 descriptores)
# Aviso: No se detectaron características en norm_clean_100PesosFront_comp_0.png.
# Procesado: norm_clean_100PesosFront_comp_3.png (27 descriptores)
# Procesado: norm_clean_100PesosFront_comp_4.png (448 descriptores)
# Aviso: No se detectaron características en norm_clean_200PesosBack_comp_0.png.
# Procesado: norm_clean_200PesosBack_comp_2.png (38 descriptores)
# Procesado: norm_clean_200PesosBack_comp_4.png (467 descriptores)
# Aviso: No se detectaron características en norm_clean_200PesosFront_comp_0.png.
# Procesado: norm_clean_200PesosFront_comp_3.png (419 descriptores)
# Procesado: norm_clean_200PesosFront_comp_4.png (24 descriptores)
# Aviso: No se detectaron características en norm_clean_20PesosBack_comp_0.png.
# Procesado: norm_clean_20PesosBack_comp_1.png (97 descriptores)
# Aviso: No se detectaron características en norm_clean_20PesosBack_comp_2.png.
# Procesado: norm_clean_20PesosBack_comp_4.png (480 descriptores)
# Aviso: No se detectaron características en norm_clean_20PesosFront_comp_0.png.
# Procesado: norm_clean_20PesosFront_comp_2.png (463 descriptores)
# Procesado: norm_clean_20PesosFront_comp_3.png (70 descriptores)
# Aviso: No se detectaron características en norm_clean_20PesosPolimeroBack_comp_0.png.
# Aviso: No se detectaron características en norm_clean_20PesosPolimeroBack_comp_2.png.
# Procesado: norm_clean_20PesosPolimeroBack_comp_3.png (61 descriptores)
# Procesado: norm_clean_20PesosPolimeroBack_comp_4.png (436 descriptores)
# Aviso: No se detectaron características en norm_clean_20PesosPolimeroFront_comp_0.png.
# Procesado: norm_clean_20PesosPolimeroFront_comp_1.png (324 descriptores)
# Aviso: No se detectaron características en norm_clean_20PesosPolimeroFront_comp_2.png.
# Procesado: norm_clean_20PesosPolimeroFront_comp_3.png (33 descriptores)
# Procesado: norm_clean_20PesosPolimeroFront_comp_5.png (477 descriptores)
# Aviso: No se detectaron características en norm_clean_500PesosBack_comp_1.png.
# Procesado: norm_clean_500PesosBack_comp_2.png (52 descriptores)
# Procesado: norm_clean_500PesosBack_comp_4.png (475 descriptores)
# Aviso: No se detectaron características en norm_clean_500PesosFront_comp_0.png.
# Procesado: norm_clean_500PesosFront_comp_3.png (35 descriptores)
# Procesado: norm_clean_500PesosFront_comp_4.png (446 descriptores)
# Aviso: No se detectaron características en norm_clean_50PesosPolimeroBack_comp_0.png.
# Procesado: norm_clean_50PesosPolimeroBack_comp_1.png (313 descriptores)
# Aviso: No se detectaron características en norm_clean_50PesosPolimeroBack_comp_2.png.
# Procesado: norm_clean_50PesosPolimeroBack_comp_4.png (33 descriptores)
# Procesado: norm_clean_50PesosPolimeroBack_comp_5.png (489 descriptores)
# Aviso: No se detectaron características en norm_clean_50PesosPolimeroFront_comp_0.png.
# Aviso: No se detectaron características en norm_clean_50PesosPolimeroFront_comp_1.png.
# Procesado: norm_clean_50PesosPolimeroFront_comp_3.png (271 descriptores)
# Procesado: norm_clean_50PesosPolimeroFront_comp_4.png (50 descriptores)
# Procesado: norm_clean_50PesosPolimeroFront_comp_5.png (437 descriptores)
#
# Extracción finalizada. Datos guardados en la base de datos ORB.
